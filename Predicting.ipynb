# %% [markdown]
# # Predicting with Director Rankings and Actor Rankings

# %% [markdown]
# ## 1. Getting the relevant datasets

# %%
#Importing the basic libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.1 Importing the datasets for:
# > 1. **Top 50 Directors**
# > 2. **Top 1000 Actors and Actresses**
# > 3. **Top 250 Films**
# > 4. **The Oscar Award**

# %% [markdown]
# #### Top 50 directors:

# %%
directorData = pd.read_csv('Top 50 directors.csv')
directorData.head()
# Out:
#    Rank      Name of Director
# 0     1      Steven Spielberg
# 1     2       Martin Scorsese
# 2     3  Francis Ford Coppola
# 3     4       Stanley Kubrick
# 4     5      Alfred Hitchcock

# %% [markdown]
# Check the vital statistics of the dataset using the type and shape attributes.

# %%
print("Data type : ", type(directorData))
print("Data dims : ", directorData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (50, 2)

# %% [markdown]
# Check the variables (and their types) in the dataset using the dtypes attribute.

# %%
print(directorData.dtypes)
# Out:
# Rank                 int64
# Name of Director    object
# dtype: object

# %% [markdown]
# #### Top 1000 actors and actresses:

# %%
actorData = pd.read_csv('Top 1000 Actors and Actresses.csv')
actorData.head()
# Out:
#    Position      Const     Created    Modified  Description  \
# 0         1  nm0000134  2014-03-09  2014-03-09          NaN
# 1         2  nm0000197  2014-03-09  2015-10-25          NaN
# 2         3  nm0000008  2014-03-09  2014-03-09          NaN
# 3         4  nm0000243  2014-03-09  2014-03-09          NaN
# 4         5  nm0000031  2014-03-09  2014-03-09          NaN
#
#                 Name           Known For  Birth Date
# 0     Robert De Niro         Raging Bull  1943-08-17
# 1     Jack Nicholson           Chinatown  1937-04-22
# 2      Marlon Brando      Apocalypse Now  1924-04-03
# 3  Denzel Washington              Fences  1954-12-28
# 4  Katharine Hepburn  The Lion in Winter  1907-05-12

# %% [markdown]
# Check the vital statistics of the dataset using the type and shape attributes.

# %%
print("Data type : ", type(actorData))
print("Data dims : ", actorData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1000, 8)

# %% [markdown]
# Check the variables (and their types) in the dataset using the dtypes attribute.

# %%
print(actorData.dtypes)
# Out:
# Position         int64
# Const           object
# Created         object
# Modified        object
# Description    float64
# Name            object
# Known For       object
# Birth Date      object
# dtype: object

# %% [markdown]
# #### Top 250 films:

# %%
imdbData = pd.read_csv('imdbTop250.csv')
imdbData.head()
# Out:
#    Ranking  IMDByear           IMDBlink                               Title  \
# 0        1      1996  /title/tt0076759/  Star Wars: Episode IV - A New Hope
# 1        2      1996  /title/tt0111161/            The Shawshank Redemption
# 2        3      1996  /title/tt0117951/                       Trainspotting
# 3        4      1996  /title/tt0114814/                  The Usual Suspects
# 4        5      1996  /title/tt0108598/                  The Wrong Trousers
#
#    Date  RunTime                       Genre  Rating  Score    Votes   Gross  \
# 0  1977      121  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1  1994      142                       Drama     9.3   80.0  2529673   28.34
# 2  1996       93                       Drama     8.1   83.0   665213   16.50
# 3  1995      106       Crime, Drama, Mystery     8.5   77.0  1045626   23.34
# 4  1993       30    Animation, Short, Comedy     8.3    NaN    53316     NaN
#
#          Director           Cast1             Cast2               Cast3  \
# 0    George Lucas     Mark Hamill     Harrison Ford       Carrie Fisher
# 1  Frank Darabont     Tim Robbins    Morgan Freeman          Bob Gunton
# 2     Danny Boyle   Ewan McGregor      Ewen Bremner    Jonny Lee Miller
# 3    Bryan Singer    Kevin Spacey     Gabriel Byrne    Chazz Palminteri
# 4       Nick Park    Peter Sallis     Peter Hawkins                 NaN
#
#                Cast4
# 0      Alec Guinness
# 1     William Sadler
# 2       Kevin McKidd
# 3    Stephen Baldwin
# 4                NaN

# %% [markdown]
# Check the vital statistics of the dataset using the type and shape attributes.

# %%
print("Data type : ", type(imdbData))
print("Data dims : ", imdbData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (6500, 16)

# %% [markdown]
# Check the variables (and their types) in the dataset using the dtypes attribute.

# %%
print(imdbData.dtypes)
# Out:
# Ranking       int64
# IMDByear      int64
# IMDBlink     object
# Title        object
# Date          int64
# RunTime       int64
# Genre        object
# Rating      float64
# Score       float64
# Votes         int64
# Gross       float64
# Director     object
# Cast1        object
# Cast2        object
# Cast3        object
# Cast4        object
# dtype: object

# %% [markdown]
# #### The Oscar Award:

# %%
awardData = pd.read_csv('clean_oscarAward.csv')
awardData.head()
# Out:
#    Unnamed: 0  year_film  year_ceremony  ceremony category  \
# 0           0       1927           1928         1    ACTOR
# 1           1       1927           1928         1    ACTOR
# 2           2       1927           1928         1  ACTRESS
# 3           3       1927           1928         1  ACTRESS
# 4           4       1927           1928         1  ACTRESS
#
#                   name              film  winner  Number of wins
# 0  Richard Barthelmess         The Noose   False               0
# 1        Emil Jannings  The Last Command    True               1
# 2       Louise Dresser   A Ship Comes In   False               0
# 3         Janet Gaynor        7th Heaven    True               3
# 4       Gloria Swanson    Sadie Thompson   False               0

# %% [markdown]
# Check the vital statistics of the dataset using the type and shape attributes.

# %%
print("Data type : ", type(awardData))
print("Data dims : ", awardData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (4834, 9)

# %% [markdown]
# Check the variables (and their types) in the dataset using the dtypes attribute.

# %%
print(awardData.dtypes)
# Out:
# Unnamed: 0         int64
# year_film          int64
# year_ceremony      int64
# ceremony           int64
# category          object
# name              object
# film              object
# winner              bool
# Number of wins     int64
# dtype: object

# %% [markdown]
# ### 1.2 Adding directorData and actorData into imdbData

# %% [markdown]
# #### Inserting columns into imdbData:
#
# Default value of cast ranks is set as 100000 - allows the rankings of the top 250 actors and actresses to weigh more
# Default value of sum of rankings is set as 400000 - sum of the default value of all cast ranks

# %%
imdbData.insert(12, "Director Rank", 0)
imdbData.insert(14, "Cast1 Rank", 100000)
imdbData.insert(16, "Cast2 Rank", 100000)
imdbData.insert(18, "Cast3 Rank", 100000)
imdbData.insert(20, "Cast4 Rank", 100000)
imdbData.insert(21, "Sum of Rankings", 400000)

# %%
imdbData
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# 6495               The Battle of Algiers  1966      121
# 6496                   Nights of Cabiria  1957      110
# 6497                  The Princess Bride  1987       98
# 6498                          Raatchasan  2018      170
# 6499                        Sardar Udham  2021      164
#
#                            Genre  Rating  Score    Votes  ...  Director Rank  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  ...              0
# 1                          Drama     9.3   80.0  2529673  ...              0
# 2                          Drama     8.1   83.0   665213  ...              0
# 3          Crime, Drama, Mystery     8.5   77.0  1045626  ...              0
# 4       Animation, Short, Comedy     8.3    NaN    53316  ...              0
# ...                          ...     ...    ...      ...  ...            ...
# 6495                  Drama, War     8.1   96.0    57995  ...              0
# 6496                       Drama     8.1    NaN    47318  ...              0
# 6497  Adventure, Family, Fantasy     8.1   77.0   416207  ...              0
# 6498       Crime, Drama, Mystery     8.4    NaN    37474  ...              0
# 6499     Biography, Crime, Drama     8.7    NaN    34889  ...              0
#
#                   Cast1  Cast1 Rank              Cast2  Cast2 Rank  \
# 0           Mark Hamill      100000      Harrison Ford      100000
# 1           Tim Robbins      100000     Morgan Freeman      100000
# 2         Ewan McGregor      100000       Ewen Bremner      100000
# 3          Kevin Spacey      100000      Gabriel Byrne      100000
# 4          Peter Sallis      100000      Peter Hawkins      100000
# ...                 ...         ...                ...         ...
# 6495     Brahim Hadjadj      100000        Jean Martin      100000
# 6496   Giulietta Masina      100000    François Périer      100000
# 6497         Cary Elwes      100000     Mandy Patinkin      100000
# 6498      Vishnu Vishal      100000         Amala Paul      100000
# 6499      Vicky Kaushal      100000      Banita Sandhu      100000
#
#                    Cast3  Cast3 Rank              Cast4  Cast4 Rank  \
# 0          Carrie Fisher      100000      Alec Guinness      100000
# 1             Bob Gunton      100000     William Sadler      100000
# 2       Jonny Lee Miller      100000       Kevin McKidd      100000
# 3       Chazz Palminteri      100000    Stephen Baldwin      100000
# 4                    NaN      100000                NaN      100000
# ...                  ...         ...                ...         ...
# 6495         Yacef Saadi      100000      Samia Kerbash      100000
# 6496        Franca Marzi      100000        Dorian Gray      100000
# 6497        Robin Wright      100000     Chris Sarandon      100000
# 6498          Radha Ravi      100000    Sangili Murugan      100000
# 6499         Shaun Scott      100000      Stephen Hogan      100000
#
#      Sum of Rankings
# 0             400000
# 1             400000
# 2             400000
# 3             400000
# 4             400000
# ...              ...
# 6495          400000
# 6496          400000
# 6497          400000
# 6498          400000
# 6499          400000
#
# [6500 rows x 22 columns]

# %% [markdown]
# #### Adding director rankings to the IMDB Dataset using data from the Top 50 Directors dataset:

# %%
yes = 0
for i in range(0,len(imdbData)):
    for j in range(0,len(directorData)):
        if(imdbData['Director'][i] == directorData['Name of Director'][j]):
            imdbData.at[i,'Director Rank'] = directorData['Rank'][j]
            yes = 1
    if yes != 1:
        imdbData.at[i,'Director Rank']='0'
    yes = 0

# %%
imdbData
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# 6495               The Battle of Algiers  1966      121
# 6496                   Nights of Cabiria  1957      110
# 6497                  The Princess Bride  1987       98
# 6498                          Raatchasan  2018      170
# 6499                        Sardar Udham  2021      164
#
#                            Genre  Rating  Score    Votes  ...  Director Rank  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  ...              0
# 1                          Drama     9.3   80.0  2529673  ...             20
# 2                          Drama     8.1   83.0   665213  ...             36
# 3          Crime, Drama, Mystery     8.5   77.0  1045626  ...             43
# 4       Animation, Short, Comedy     8.3    NaN    53316  ...              0
# ...                          ...     ...    ...      ...  ...            ...
# 6495                  Drama, War     8.1   96.0    57995  ...              0
# 6496                       Drama     8.1    NaN    47318  ...              0
# 6497  Adventure, Family, Fantasy     8.1   77.0   416207  ...              0
# 6498       Crime, Drama, Mystery     8.4    NaN    37474  ...              0
# 6499     Biography, Crime, Drama     8.7    NaN    34889  ...              0
#
#                   Cast1  Cast1 Rank              Cast2  Cast2 Rank  \
# 0           Mark Hamill      100000      Harrison Ford      100000
# 1           Tim Robbins      100000     Morgan Freeman      100000
# 2         Ewan McGregor      100000       Ewen Bremner      100000
# 3          Kevin Spacey      100000      Gabriel Byrne      100000
# 4          Peter Sallis      100000      Peter Hawkins      100000
# ...                 ...         ...                ...         ...
# 6495     Brahim Hadjadj      100000        Jean Martin      100000
# 6496   Giulietta Masina      100000    François Périer      100000
# 6497         Cary Elwes      100000     Mandy Patinkin      100000
# 6498      Vishnu Vishal      100000         Amala Paul      100000
# 6499      Vicky Kaushal      100000      Banita Sandhu      100000
#
#                    Cast3  Cast3 Rank              Cast4  Cast4 Rank  \
# 0          Carrie Fisher      100000      Alec Guinness      100000
# 1             Bob Gunton      100000     William Sadler      100000
# 2       Jonny Lee Miller      100000       Kevin McKidd      100000
# 3       Chazz Palminteri      100000    Stephen Baldwin      100000
# 4                    NaN      100000                NaN      100000
# ...                  ...         ...                ...         ...
# 6495         Yacef Saadi      100000      Samia Kerbash      100000
# 6496        Franca Marzi      100000        Dorian Gray      100000
# 6497        Robin Wright      100000     Chris Sarandon      100000
# 6498          Radha Ravi      100000    Sangili Murugan      100000
# 6499         Shaun Scott      100000      Stephen Hogan      100000
#
#      Sum of Rankings
# 0             400000
# 1             400000
# 2             400000
# 3             400000
# 4             400000
# ...              ...
# 6495          400000
# 6496          400000
# 6497          400000
# 6498          400000
# 6499          400000
#
# [6500 rows x 22 columns]

# %% [markdown]
# #### Adding Cast1 rankings to the IMDB Dataset using data from the Top 1000 Actors and Actresses dataset:

# %%
yes = 0
for i in range(0,len(imdbData)):
    for j in range(0,len(actorData)):
        if(imdbData['Cast1'][i].strip() == actorData['Name'][j]):
            imdbData.at[i,'Cast1 Rank'] = actorData['Position'][j]
            yes = 1
    if yes != 1:
        imdbData.at[i,'Cast1 Rank']='100000'
    yes = 0

# %%
imdbData
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# 6495               The Battle of Algiers  1966      121
# 6496                   Nights of Cabiria  1957      110
# 6497                  The Princess Bride  1987       98
# 6498                          Raatchasan  2018      170
# 6499                        Sardar Udham  2021      164
#
#                            Genre  Rating  Score    Votes  ...  Director Rank  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  ...              0
# 1                          Drama     9.3   80.0  2529673  ...             20
# 2                          Drama     8.1   83.0   665213  ...             36
# 3          Crime, Drama, Mystery     8.5   77.0  1045626  ...             43
# 4       Animation, Short, Comedy     8.3    NaN    53316  ...              0
# ...                          ...     ...    ...      ...  ...            ...
# 6495                  Drama, War     8.1   96.0    57995  ...              0
# 6496                       Drama     8.1    NaN    47318  ...              0
# 6497  Adventure, Family, Fantasy     8.1   77.0   416207  ...              0
# 6498       Crime, Drama, Mystery     8.4    NaN    37474  ...              0
# 6499     Biography, Crime, Drama     8.7    NaN    34889  ...              0
#
#                   Cast1  Cast1 Rank              Cast2  Cast2 Rank  \
# 0           Mark Hamill         914      Harrison Ford      100000
# 1           Tim Robbins         159     Morgan Freeman      100000
# 2         Ewan McGregor         713       Ewen Bremner      100000
# 3          Kevin Spacey         618      Gabriel Byrne      100000
# 4          Peter Sallis      100000      Peter Hawkins      100000
# ...                 ...         ...                ...         ...
# 6495     Brahim Hadjadj      100000        Jean Martin      100000
# 6496   Giulietta Masina      100000    François Périer      100000
# 6497         Cary Elwes         903     Mandy Patinkin      100000
# 6498      Vishnu Vishal      100000         Amala Paul      100000
# 6499      Vicky Kaushal      100000      Banita Sandhu      100000
#
#                    Cast3  Cast3 Rank              Cast4  Cast4 Rank  \
# 0          Carrie Fisher      100000      Alec Guinness      100000
# 1             Bob Gunton      100000     William Sadler      100000
# 2       Jonny Lee Miller      100000       Kevin McKidd      100000
# 3       Chazz Palminteri      100000    Stephen Baldwin      100000
# 4                    NaN      100000                NaN      100000
# ...                  ...         ...                ...         ...
# 6495         Yacef Saadi      100000      Samia Kerbash      100000
# 6496        Franca Marzi      100000        Dorian Gray      100000
# 6497        Robin Wright      100000     Chris Sarandon      100000
# 6498          Radha Ravi      100000    Sangili Murugan      100000
# 6499         Shaun Scott      100000      Stephen Hogan      100000
#
#      Sum of Rankings
# 0             400000
# 1             400000
# 2             400000
# 3             400000
# 4             400000
# ...              ...
# 6495          400000
# 6496          400000
# 6497          400000
# 6498          400000
# 6499          400000
#
# [6500 rows x 22 columns]

# %% [markdown]
# #### Adding Cast2 rankings to the IMDB Dataset using data from the Top 1000 Actors and Actresses dataset:

# %%
yes = 0
for i in range(0,len(imdbData)):
    for j in range(0,len(actorData)):
        if(imdbData['Cast2'][i].strip() == actorData['Name'][j]):
            imdbData.at[i,'Cast2 Rank'] = actorData['Position'][j]
            yes = 1
    if yes != 1:
        imdbData.at[i,'Cast2 Rank']='100000'
    yes = 0

# %% [markdown]
# #### Adding Cast3 rankings to the IMDB Dataset using data from the Top 1000 Actors and Actresses dataset:

# %%
yes = 0
for i in range(0,len(imdbData)):
    if(type(imdbData['Cast3'][i]) == float):
        continue
    else:
        for j in range(0,len(actorData)):
            if(imdbData['Cast3'][i].strip() == actorData['Name'][j]):
                imdbData.at[i,'Cast3 Rank'] = actorData['Position'][j]
                yes = 1
    if yes != 1:
        imdbData.at[i,'Cast3 Rank']='100000'
    yes = 0

# %% [markdown]
# #### Adding Cast4 rankings to the IMDB Dataset using data from the Top 1000 Actors and Actresses dataset:

# %%
yes = 0
for i in range(0,len(imdbData)):
    if(type(imdbData['Cast4'][i]) == float):
        continue
    else:
        for j in range(0,len(actorData)):
            if(imdbData['Cast4'][i].strip() == actorData['Name'][j]):
                imdbData.at[i,'Cast4 Rank'] = actorData['Position'][j]
                yes = 1
    if yes != 1:
        imdbData.at[i,'Cast4 Rank']='100000'
    yes = 0

# %% [markdown]
# #### Adding sum of cast rankings to the IMDB Dataset using data from the Top 1000 Actors and Actresses dataset:

# %%
sum = 0
for i in range(0,len(imdbData)):
    sum += imdbData['Cast1 Rank'][i] + imdbData['Cast2 Rank'][i] + imdbData['Cast3 Rank'][i] + imdbData['Cast4 Rank'][i]
    imdbData.at[i,'Sum of Rankings'] = sum
    sum = 0

# %% [markdown]
# #### New imdbData dataset:

# %%
imdbData
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# 6495               The Battle of Algiers  1966      121
# 6496                   Nights of Cabiria  1957      110
# 6497                  The Princess Bride  1987       98
# 6498                          Raatchasan  2018      170
# 6499                        Sardar Udham  2021      164
#
#                            Genre  Rating  Score    Votes  ...  Director Rank  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  ...              0
# 1                          Drama     9.3   80.0  2529673  ...             20
# 2                          Drama     8.1   83.0   665213  ...             36
# 3          Crime, Drama, Mystery     8.5   77.0  1045626  ...             43
# 4       Animation, Short, Comedy     8.3    NaN    53316  ...              0
# ...                          ...     ...    ...      ...  ...            ...
# 6495                  Drama, War     8.1   96.0    57995  ...              0
# 6496                       Drama     8.1    NaN    47318  ...              0
# 6497  Adventure, Family, Fantasy     8.1   77.0   416207  ...              0
# 6498       Crime, Drama, Mystery     8.4    NaN    37474  ...              0
# 6499     Biography, Crime, Drama     8.7    NaN    34889  ...              0
#
#                   Cast1  Cast1 Rank              Cast2  Cast2 Rank  \
# 0           Mark Hamill         914      Harrison Ford          58
# 1           Tim Robbins         159     Morgan Freeman          34
# 2         Ewan McGregor         713       Ewen Bremner      100000
# 3          Kevin Spacey         618      Gabriel Byrne      100000
# 4          Peter Sallis      100000      Peter Hawkins      100000
# ...                 ...         ...                ...         ...
# 6495     Brahim Hadjadj      100000        Jean Martin      100000
# 6496   Giulietta Masina      100000    François Périer      100000
# 6497         Cary Elwes         903     Mandy Patinkin      100000
# 6498      Vishnu Vishal      100000         Amala Paul      100000
# 6499      Vicky Kaushal      100000      Banita Sandhu      100000
#
#                    Cast3  Cast3 Rank              Cast4  Cast4 Rank  \
# 0          Carrie Fisher         731      Alec Guinness         165
# 1             Bob Gunton      100000     William Sadler      100000
# 2       Jonny Lee Miller      100000       Kevin McKidd      100000
# 3       Chazz Palminteri         771    Stephen Baldwin      100000
# 4                    NaN      100000                NaN      100000
# ...                  ...         ...                ...         ...
# 6495         Yacef Saadi      100000      Samia Kerbash      100000
# 6496        Franca Marzi      100000        Dorian Gray      100000
# 6497        Robin Wright         340     Chris Sarandon      100000
# 6498          Radha Ravi      100000    Sangili Murugan      100000
# 6499         Shaun Scott      100000      Stephen Hogan      100000
#
#      Sum of Rankings
# 0               1868
# 1             200193
# 2             300713
# 3             201389
# 4             400000
# ...              ...
# 6495          400000
# 6496          400000
# 6497          201243
# 6498          400000
# 6499          400000
#
# [6500 rows x 22 columns]

# %%
imdbData.to_csv('IMDBtotal.csv')
