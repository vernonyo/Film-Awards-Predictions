# %% [markdown]
# ## Importing the basic libraries:

# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# ### Add all the dataframes from the box office website for years 1977-2022 into a list:

# %%
list = []

for i in range(1977, 2023):
    url = f'https://www.boxofficemojo.com/year/world/{i}'
    df = pd.read_html(url)
    print(url)
    dfOld = df[0]
    dfOld.insert(3, "Release Year", i)
    list.append(dfOld)
# Out:
# https://www.boxofficemojo.com/year/world/1977
# https://www.boxofficemojo.com/year/world/1978
# https://www.boxofficemojo.com/year/world/1979
# https://www.boxofficemojo.com/year/world/1980
# https://www.boxofficemojo.com/year/world/1981
# https://www.boxofficemojo.com/year/world/1982
# https://www.boxofficemojo.com/year/world/1983
# https://www.boxofficemojo.com/year/world/1984
# https://www.boxofficemojo.com/year/world/1985
# https://www.boxofficemojo.com/year/world/1986
# https://www.boxofficemojo.com/year/world/1987
# https://www.boxofficemojo.com/year/world/1988
# https://www.boxofficemojo.com/year/world/1989
# https://www.boxofficemojo.com/year/world/1990
# https://www.boxofficemojo.com/year/world/1991
# https://www.boxofficemojo.com/year/world/1992
# https://www.boxofficemojo.com/year/world/1993
# https://www.boxofficemojo.com/year/world/1994
# https://www.boxofficemojo.com/year/world/1995
# https://www.boxofficemojo.com/year/world/1996
# ...

# %% [markdown]
# ### Combining all dataframes into one dataframe:

# %%
salesData = pd.concat(list, ignore_index=True)

# %%
salesData
# Out:
#       Rank                       Release Group     Worldwide  Release Year  \
# 0        1                           Star Wars  $307,263,857          1977
# 1        2               Smokey and the Bandit  $126,737,428          1977
# 2        3  Close Encounters of the Third Kind  $116,395,460          1977
# 3        4                Saturday Night Fever   $94,213,184          1977
# 4        5                    A Bridge Too Far   $50,750,000          1977
# ...    ...                                 ...           ...           ...
# 8435   196              The World of Yesterday      $454,263          2022
# 8436   197                        Murder Party      $453,590          2022
# 8437   198                  The Desperate Hour      $447,533          2022
# 8438   199         Eiga Odd Taxi: In the Woods      $437,828          2022
# 8439   200              Selena 2022 Re-release      $437,322          2022
#
#           Domestic     %   Foreign   %.1
# ...

# %% [markdown]
# ###### Checking the variables:

# %%
salesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8440 entries, 0 to 8439
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           8440 non-null   int64
#  1   Release Group  8440 non-null   object
#  2   Worldwide      8440 non-null   object
#  3   Release Year   8440 non-null   int64
#  4   Domestic       8440 non-null   object
#  5   %              8440 non-null   object
#  6   Foreign        8440 non-null   object
#  7   %.1            8440 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 527.6+ KB

# %%
salesData.to_csv('salesData.csv')
