# %% [markdown]
# ## Import the necessary basic libraries

# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# ## Obtaining the datasets for:
# > 1. **Top 50 Directors**
# > 2. **Top 1000 Actors and Actresses**
# > 3. **The Oscar Award**
# ------------------------

# %% [markdown]
# ###### Top 50 Directors dataset:

# %%
# The dataset is in CSV format, hence we use the read_csv function from Pandas.
# Immediately after importing, we will take a quick look at the data using the head function.
directorData = pd.read_csv('Top 50 directors.csv')
directorData.head()
# Out:
#    Rank      Name of Director
# 0     1      Steven Spielberg
# 1     2       Martin Scorsese
# 2     3  Francis Ford Coppola
# 3     4       Stanley Kubrick
# 4     5      Alfred Hitchcock

# %% [markdown]
# Check the vital statistics of the dataset using the `type` and `shape` attributes.

# %%
print("Data type : ", type(directorData))
print("Data dims : ", directorData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (50, 2)

# %% [markdown]
# Check the variables (and their types) in the dataset using the `dtypes` attribute.

# %%
print(directorData.dtypes)
# Out:
# Rank                 int64
# Name of Director    object
# dtype: object

# %% [markdown]
# ###### Top 1000 Actors and Actresses dataset:

# %%
# The dataset is in CSV format, hence we use the read_csv function from Pandas.
# Immediately after importing, we will take a quick look at the data using the head function.
actorData = pd.read_csv('Top 1000 Actors and Actresses.csv')
actorData.head()
# Out:
#    Position      Const     Created    Modified  Description  \
# 0         1  nm0000134  2014-03-09  2014-03-09          NaN
# 1         2  nm0000197  2014-03-09  2015-10-25          NaN
# 2         3  nm0000008  2014-03-09  2014-03-09          NaN
# 3         4  nm0000243  2014-03-09  2014-03-09          NaN
# 4         5  nm0000031  2014-03-09  2014-03-09          NaN
#
#                 Name           Known For  Birth Date
# 0     Robert De Niro         Raging Bull  1943-08-17
# 1     Jack Nicholson           Chinatown  1937-04-22
# 2      Marlon Brando      Apocalypse Now  1924-04-03
# 3  Denzel Washington              Fences  1954-12-28
# 4  Katharine Hepburn  The Lion in Winter  1907-05-12

# %% [markdown]
# Check the vital statistics of the dataset using the `type` and `shape` attributes.

# %%
print("Data type : ", type(actorData))
print("Data dims : ", actorData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1000, 8)

# %% [markdown]
# Check the variables (and their types) in the dataset using the `dtypes` attribute.

# %%
print(actorData.dtypes)
# Out:
# Position         int64
# Const           object
# Created         object
# Modified        object
# Description    float64
# Name            object
# Known For       object
# Birth Date      object
# dtype: object

# %% [markdown]
# ###### Oscar Award dataset:

# %%
# The dataset is in CSV format, hence we use the read_csv function from Pandas.
# Immediately after importing, we will take a quick look at the data using the head function.
oscarData = pd.read_csv('oscarData.csv')
oscarData.head()
# Out:
#    Unnamed: 0             Title  Year           Genre Genre 1  Rating  \
# 0           0           Sunrise  1927  Drama, Romance   Drama     8.1
# 1           1             Wings  1927  Drama, Romance   Drama     7.6
# 2           2   Hollywood Revue  1928   Comedy, Music  Comedy     5.8
# 3           3           Morocco  1930  Drama, Romance   Drama     7.0
# 4           4  The Public Enemy  1930    Crime, Drama   Crime     7.6
#
#                     Runtime    Sales  \
# 0   1   hour   34   minutes   121107
# 1  2   hours   24   minutes      746
# 2  2   hours   10   minutes  5277780
# 3   1   hour   32   minutes      191
# 4   1   hour   23   minutes  1214260
#
#                                     Language Age Rating English Film  \
# 0                              None, English     Passed           No
# 1                                    English       PG13          Yes
# 2                                    English     Passed          Yes
# 3  English, French, Spanish, Arabic, Italian     Passed          Yes
# 4                                    English  Not Rated          Yes
#
#               Director           Cast1                   Cast2  \
# 0          F.W. Murnau  George O'Brien            Janet Gaynor
# 1   William A. Wellman       Clara Bow  Charles 'Buddy' Rogers
# 2      Charles Reisner    Conrad Nagel              Jack Benny
# 3  Josef von Sternberg     Gary Cooper        Marlene Dietrich
# 4   William A. Wellman    James Cagney             Jean Harlow
#
#                  Cast3 Country of Origin Country of Origin 1  Number of Wins
# 0  Margaret Livingston     United States       United States               3
# 1        Richard Arlen     United States       United States               1
# 2         John Gilbert     United States       United States               0
# 3       Adolphe Menjou     United States       United States               0
# 4         Edward Woods     United States       United States               0

# %% [markdown]
# Check the vital statistics of the dataset using the `type` and `shape` attributes.

# %%
print("Data type : ", type(oscarData))
print("Data dims : ", oscarData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1658, 18)

# %% [markdown]
# Check the variables (and their types) in the dataset using the `dtypes` attribute.

# %%
print(oscarData.dtypes)
# Out:
# Unnamed: 0               int64
# Title                   object
# Year                     int64
# Genre                   object
# Genre 1                 object
# Rating                 float64
# Runtime                 object
# Sales                    int64
# Language                object
# Age Rating              object
# English Film            object
# Director                object
# Cast1                   object
# Cast2                   object
# Cast3                   object
# Country of Origin       object
# Country of Origin 1     object
# Number of Wins           int64
# dtype: object

# %% [markdown]
# ## Adding our variables to the dataset

# %% [markdown]
# As we are using the actors' and directors' popularity to determine the number of times a film wins at the Oscar Awards, we need to add these variables to the dataset using the existing actor and directors names.

# %% [markdown]
# We begin by adding columns into the oscarData dataframe.

# %% [markdown]
# This includes:
# > 1. Cast1 Ranking
# > 2. Cast2 Ranking
# > 3. Cast3 Ranking
# > 4. Director Ranking
# > 5. Sum of Rankings

# %% [markdown]
# The default value of director ranks is set as 100000. This allows the rankings of the top 50 Directors to weigh more.

# %%
oscarData.insert(9, "Director Rank", 100000)

# %% [markdown]
# The default value of cast ranks is also set as 100000. This allows the rankings of the top 1000 Actors and Actresses to weigh more.
# Henceforth, the default value of sum of cast rankings is set at 400000, which is the sum of default value of all the cast ranks.

# %%
oscarData.insert(11, "Cast1 Rank", 100000)
oscarData.insert(13, "Cast2 Rank", 100000)
oscarData.insert(15, "Cast3 Rank", 100000)
oscarData.insert(16, "Sum of Cast Rankings", 400000)

# %% [markdown]
# The new dataframe:

# %%
oscarData.head()
# Out:
#    Unnamed: 0             Title  Year           Genre Genre 1  Rating  \
# 0           0           Sunrise  1927  Drama, Romance   Drama     8.1
# 1           1             Wings  1927  Drama, Romance   Drama     7.6
# 2           2   Hollywood Revue  1928   Comedy, Music  Comedy     5.8
# 3           3           Morocco  1930  Drama, Romance   Drama     7.0
# 4           4  The Public Enemy  1930    Crime, Drama   Crime     7.6
#
#                     Runtime    Sales  \
# 0   1   hour   34   minutes   121107
# 1  2   hours   24   minutes      746
# 2  2   hours   10   minutes  5277780
# 3   1   hour   32   minutes      191
# 4   1   hour   23   minutes  1214260
#
#                                     Language  Director Rank  ... Cast2 Rank  \
# 0                              None, English         100000  ...     100000
# 1                                    English         100000  ...     100000
# 2                                    English         100000  ...     100000
# 3  English, French, Spanish, Arabic, Italian         100000  ...     100000
# 4                                    English         100000  ...     100000
#
#               Director Cast3 Rank  Sum of Cast Rankings           Cast1  \
# 0          F.W. Murnau     100000                400000  George O'Brien
# 1   William A. Wellman     100000                400000       Clara Bow
# 2      Charles Reisner     100000                400000    Conrad Nagel
# 3  Josef von Sternberg     100000                400000     Gary Cooper
# 4   William A. Wellman     100000                400000    James Cagney
#
#                     Cast2                Cast3 Country of Origin  \
# 0            Janet Gaynor  Margaret Livingston     United States
# 1  Charles 'Buddy' Rogers        Richard Arlen     United States
# 2              Jack Benny         John Gilbert     United States
# 3        Marlene Dietrich       Adolphe Menjou     United States
# 4             Jean Harlow         Edward Woods     United States
#
#   Country of Origin 1 Number of Wins
# 0       United States              3
# 1       United States              1
# 2       United States              0
# 3       United States              0
# 4       United States              0
#
# [5 rows x 23 columns]

# %% [markdown]
# Now, we will add the corresponding director and cast ranks.

# %%
#Adding the director ranks by comparing the name of the director in the oscarData dataframe and that in our directorData dataframe.
#Those that do not have a rank in the directorData dataframe will be assigned a rank of 100000.
#This places more weight on those directors who have a rank.
yes = 0
for i in range(0,len(oscarData)):
    for j in range(0,len(directorData)):
        if(oscarData['Director'][i] == directorData['Name of Director'][j]):
            oscarData.at[i,'Director Rank'] = directorData['Rank'][j]
            yes = 1
    if yes != 1:
        oscarData.at[i,'Director Rank'] = '100000'
    yes = 0

# %%
#Adding the cast ranks by comparing the name of the cast in the oscarData dataframe and that in our directorData dataframe.
#Those that do not have a rank in the directorData dataframe will be assigned a rank of 100000.
#This places more weight on those casts who have a rank.
yes1 = 0
yes2 = 0
yes3 = 0
for i in range(0,len(oscarData)):
    for j in range(0,len(actorData)):
        if(oscarData['Cast1'][i].strip() == actorData['Name'][j]):
            oscarData.at[i,'Cast1 Rank'] = actorData['Position'][j]
            yes1 = 1
            
        if(oscarData['Cast2'][i].strip() == actorData['Name'][j]):
            oscarData.at[i,'Cast2 Rank'] = actorData['Position'][j]
            yes2 = 1
            
        if(oscarData['Cast3'][i].strip() == actorData['Name'][j]):
            oscarData.at[i,'Cast3 Rank'] = actorData['Position'][j]
            yes3 = 1
    #if there was no corresponding rank data, the rank remains at 100000        
    if yes1 != 1:
        oscarData.at[i,'Cast1 Rank'] = '100000'
        
    if yes2 != 1:
        oscarData.at[i,'Cast2 Rank'] = '100000'
        
    if yes3 != 1:
        oscarData.at[i,'Cast3 Rank'] = '100000'
    #initialize all yes variables back to 0
    yes1 = 0
    yes2 = 0
    yes3 = 0

# %%
#Adding the Sum of Cast Rankings
sum = 0

for i in range(0,len(oscarData)):
    sum += oscarData['Cast1 Rank'][i] + oscarData['Cast2 Rank'][i] + oscarData['Cast3 Rank'][i]
    oscarData.at[i,'Sum of Cast Rankings'] = sum
    sum = 0

# %% [markdown]
# ###### The new oscarData dataframe:

# %%
oscarData.head()
# Out:
#    Unnamed: 0             Title  Year           Genre Genre 1  Rating  \
# 0           0           Sunrise  1927  Drama, Romance   Drama     8.1
# 1           1             Wings  1927  Drama, Romance   Drama     7.6
# 2           2   Hollywood Revue  1928   Comedy, Music  Comedy     5.8
# 3           3           Morocco  1930  Drama, Romance   Drama     7.0
# 4           4  The Public Enemy  1930    Crime, Drama   Crime     7.6
#
#                     Runtime    Sales  \
# 0   1   hour   34   minutes   121107
# 1  2   hours   24   minutes      746
# 2  2   hours   10   minutes  5277780
# 3   1   hour   32   minutes      191
# 4   1   hour   23   minutes  1214260
#
#                                     Language  Director Rank  ... Cast2 Rank  \
# 0                              None, English         100000  ...        387
# 1                                    English         100000  ...     100000
# 2                                    English         100000  ...     100000
# 3  English, French, Spanish, Arabic, Italian         100000  ...        241
# 4                                    English         100000  ...        244
#
#               Director Cast3 Rank  Sum of Cast Rankings           Cast1  \
# 0          F.W. Murnau     100000                200387  George O'Brien
# 1   William A. Wellman     100000                300000       Clara Bow
# 2      Charles Reisner     100000                300000    Conrad Nagel
# 3  Josef von Sternberg     100000                100312     Gary Cooper
# 4   William A. Wellman     100000                100284    James Cagney
#
#                     Cast2                Cast3 Country of Origin  \
# 0            Janet Gaynor  Margaret Livingston     United States
# 1  Charles 'Buddy' Rogers        Richard Arlen     United States
# 2              Jack Benny         John Gilbert     United States
# 3        Marlene Dietrich       Adolphe Menjou     United States
# 4             Jean Harlow         Edward Woods     United States
#
#   Country of Origin 1 Number of Wins
# 0       United States              3
# 1       United States              1
# 2       United States              0
# 3       United States              0
# 4       United States              0
#
# [5 rows x 23 columns]

# %%
oscarData.to_csv("temp.csv")

# %%
oscarData = pd.read_csv("temp.csv")
oscarData
# Out:
#       Unnamed: 0  Unnamed: 0.1              Title  Year                 Genre  \
# 0              0             0            Sunrise  1927        Drama, Romance
# 1              1             1              Wings  1927        Drama, Romance
# 2              2             2    Hollywood Revue  1928         Comedy, Music
# 3              3             3            Morocco  1930        Drama, Romance
# 4              4             4   The Public Enemy  1930          Crime, Drama
# ...          ...           ...                ...   ...                   ...
# 1653        1653          1653          Frozen II  2019  Animation, Adventure
# 1654        1654          1654           Ad Astra  2019      Adventure, Drama
# 1655        1655          1655  Avengers: Endgame  2019     Action, Adventure
# 1656        1656          1656      The Lion King  2019  Animation, Adventure
# 1657        1657          1657         Knives Out  2019         Comedy, Crime
#
#         Genre 1  Rating                   Runtime       Sales  \
# 0         Drama     8.1   1   hour   34   minutes      121107
# 1         Drama     7.6  2   hours   24   minutes         746
# 2        Comedy     5.8  2   hours   10   minutes     5277780
# 3         Drama     7.0   1   hour   32   minutes         191
# 4         Crime     7.6   1   hour   23   minutes     1214260
# ...         ...     ...                       ...         ...
# 1653  Animation     6.8   1   hour   43   minutes  1450026933
# 1654  Adventure     6.5   2   hours   3   minutes   127461872
# 1655     Action     8.4    3   hours   1   minute  2797501328
# 1656  Animation     6.8   1   hour   58   minutes  1662899439
# 1657     Comedy     7.9  2   hours   10   minutes   311605581
#
#                                           Language  ...  Cast2 Rank  \
# 0                                    None, English  ...         387
# 1                                          English  ...      100000
# 2                                          English  ...      100000
# 3        English, French, Spanish, Arabic, Italian  ...         241
# 4                                          English  ...         244
# ...                                            ...  ...         ...
# 1653                                       English  ...      100000
# 1654                            English, Norwegian  ...         103
# 1655              English, Japanese, Xhosa, German  ...         457
# 1656  English, Xhosa, Zulu, French, Spanish, Hindi  ...         831
# 1657                       English, Spanish, Hindi  ...         457
#
#                  Director  Cast3 Rank Sum of Cast Rankings              Cast1  \
# 0             F.W. Murnau      100000               200387     George O'Brien
# 1      William A. Wellman      100000               300000          Clara Bow
# 2         Charles Reisner      100000               300000       Conrad Nagel
# 3     Josef von Sternberg      100000               100312        Gary Cooper
# 4      William A. Wellman      100000               100284       James Cagney
# ...                   ...         ...                  ...                ...
# 1653           Chris Buck         959               101291       Kristen Bell
# 1654           James Gray      100000               100223          Brad Pitt
# 1655        Anthony Russo         516                 1098  Robert Downey Jr.
# 1656          Jon Favreau         462               101293      Donald Glover
# 1657         Rian Johnson      100000               100878       Daniel Craig
#
#                        Cast2                Cast3  \
# 0               Janet Gaynor  Margaret Livingston
# 1     Charles 'Buddy' Rogers        Richard Arlen
# 2                 Jack Benny         John Gilbert
# 3           Marlene Dietrich       Adolphe Menjou
# 4                Jean Harlow         Edward Woods
# ...                      ...                  ...
# 1653            Idina Menzel             Josh Gad
# 1654         Tommy Lee Jones           Ruth Negga
# 1655             Chris Evans         Mark Ruffalo
# 1656                 Beyoncé           Seth Rogen
# 1657             Chris Evans         Ana de Armas
#
#                   Country of Origin Country of Origin 1 Number of Wins
# 0                     United States       United States              3
# 1                     United States       United States              1
# 2                     United States       United States              0
# 3                     United States       United States              0
# 4                     United States       United States              0
# ...                             ...                 ...            ...
# 1653                  United States       United States              0
# 1654   China, United States, Brazil               China              0
# 1655                  United States       United States              0
# 1656  United States, United Kingdom       United States              0
# 1657                  United States       United States              0
#
# [1658 rows x 24 columns]

# %%
#clearing unneccessary columns
del oscarData["Unnamed: 0"]
oscarData.head()
# Out:
#    Unnamed: 0.1             Title  Year           Genre Genre 1  Rating  \
# 0             0           Sunrise  1927  Drama, Romance   Drama     8.1
# 1             1             Wings  1927  Drama, Romance   Drama     7.6
# 2             2   Hollywood Revue  1928   Comedy, Music  Comedy     5.8
# 3             3           Morocco  1930  Drama, Romance   Drama     7.0
# 4             4  The Public Enemy  1930    Crime, Drama   Crime     7.6
#
#                     Runtime    Sales  \
# 0   1   hour   34   minutes   121107
# 1  2   hours   24   minutes      746
# 2  2   hours   10   minutes  5277780
# 3   1   hour   32   minutes      191
# 4   1   hour   23   minutes  1214260
#
#                                     Language  Director Rank  ... Cast2 Rank  \
# 0                              None, English         100000  ...        387
# 1                                    English         100000  ...     100000
# 2                                    English         100000  ...     100000
# 3  English, French, Spanish, Arabic, Italian         100000  ...        241
# 4                                    English         100000  ...        244
#
#               Director Cast3 Rank  Sum of Cast Rankings           Cast1  \
# 0          F.W. Murnau     100000                200387  George O'Brien
# 1   William A. Wellman     100000                300000       Clara Bow
# 2      Charles Reisner     100000                300000    Conrad Nagel
# 3  Josef von Sternberg     100000                100312     Gary Cooper
# 4   William A. Wellman     100000                100284    James Cagney
#
#                     Cast2                Cast3 Country of Origin  \
# 0            Janet Gaynor  Margaret Livingston     United States
# 1  Charles 'Buddy' Rogers        Richard Arlen     United States
# 2              Jack Benny         John Gilbert     United States
# 3        Marlene Dietrich       Adolphe Menjou     United States
# 4             Jean Harlow         Edward Woods     United States
#
#   Country of Origin 1 Number of Wins
# 0       United States              3
# 1       United States              1
# 2       United States              0
# 3       United States              0
# 4       United States              0
#
# [5 rows x 23 columns]

# %% [markdown]
# As we will be comparing runtime as a numerical variable, we need to convert the time into minutes only.

# %%
# Storing runtime as a new dataframe
runtime = pd.DataFrame(oscarData['Runtime'])
runtime.head()
# Out:
#                     Runtime
# 0   1   hour   34   minutes
# 1  2   hours   24   minutes
# 2  2   hours   10   minutes
# 3   1   hour   32   minutes
# 4   1   hour   23   minutes

# %%
#inserting the necessary columns
runtime.insert(1, "Hours", 0)
runtime.insert(2, "Minutes", 0)

# %%
for i in range(0, len(runtime)):
    if "hours" in runtime["Runtime"][i]:
        temp1 = runtime["Runtime"][i].split("hours")
        hour = temp1[0].strip()
        if "minutes" in runtime["Runtime"][i]:
            temp2 = temp1[1].split("minutes")
            minute = temp2[0].strip()
        elif "minute" in runtime["Runtime"][i]:
            temp2 = temp1[1].split("minute")
            minute = temp2[0].strip()
        
    elif "hour" in runtime["Runtime"][i]:
        temp1 = runtime["Runtime"][i].split("hour")
        hour = temp1[0].strip()
        if "minutes" in runtime["Runtime"][i]:
            temp2 = temp1[1].split("minutes")
            minute = temp2[0].strip()
        elif "minute" in runtime["Runtime"][i]:
            temp2 = temp1[1].split("minute")
            minute = temp2[0].strip()
    else:
        if "minutes" in runtime["Runtime"][i]:
            temp1 = runtime["Runtime"][i].split("minutes")
            hour = 0
            minute = temp1[0].strip()
        
        elif "minute" in runtime["Runtime"][i]:
            temp1 = runtime["Runtime"][i].split("minute")
            hour = 0
            minute = temp1[0].strip()
        
    runtime.at[i,'Hours'] = hour
    runtime.at[i,'Minutes'] = minute

# %%
#new runtime dataframe
runtime.head()
# Out:
#                     Runtime  Hours  Minutes
# 0   1   hour   34   minutes      1       34
# 1  2   hours   24   minutes      2       24
# 2  2   hours   10   minutes      2       10
# 3   1   hour   32   minutes      1       32
# 4   1   hour   23   minutes      1       23

# %%
#converting the hours into minutes and putting back the data into the oscarData dataframe
time = 0
for i in range(0, len(runtime)):
    time = int(runtime["Hours"][i])*60 + int(runtime["Minutes"][i])
    oscarData.at[i,'Runtime'] = time

# %%
oscarData
# Out:
#       Unnamed: 0.1              Title  Year                 Genre    Genre 1  \
# 0                0            Sunrise  1927        Drama, Romance      Drama
# 1                1              Wings  1927        Drama, Romance      Drama
# 2                2    Hollywood Revue  1928         Comedy, Music     Comedy
# 3                3            Morocco  1930        Drama, Romance      Drama
# 4                4   The Public Enemy  1930          Crime, Drama      Crime
# ...            ...                ...   ...                   ...        ...
# 1653          1653          Frozen II  2019  Animation, Adventure  Animation
# 1654          1654           Ad Astra  2019      Adventure, Drama  Adventure
# 1655          1655  Avengers: Endgame  2019     Action, Adventure     Action
# 1656          1656      The Lion King  2019  Animation, Adventure  Animation
# 1657          1657         Knives Out  2019         Comedy, Crime     Comedy
#
#       Rating Runtime       Sales  \
# 0        8.1      94      121107
# 1        7.6     144         746
# 2        5.8     130     5277780
# 3        7.0      92         191
# 4        7.6      83     1214260
# ...      ...     ...         ...
# 1653     6.8     103  1450026933
# 1654     6.5     123   127461872
# 1655     8.4     181  2797501328
# 1656     6.8     118  1662899439
# 1657     7.9     130   311605581
#
#                                           Language  Director Rank  ...  \
# 0                                    None, English         100000  ...
# 1                                          English         100000  ...
# 2                                          English         100000  ...
# 3        English, French, Spanish, Arabic, Italian         100000  ...
# 4                                          English         100000  ...
# ...                                            ...            ...  ...
# 1653                                       English         100000  ...
# 1654                            English, Norwegian         100000  ...
# 1655              English, Japanese, Xhosa, German         100000  ...
# 1656  English, Xhosa, Zulu, French, Spanish, Hindi         100000  ...
# 1657                       English, Spanish, Hindi         100000  ...
#
#      Cast2 Rank             Director Cast3 Rank  Sum of Cast Rankings  \
# 0           387          F.W. Murnau     100000                200387
# 1        100000   William A. Wellman     100000                300000
# 2        100000      Charles Reisner     100000                300000
# 3           241  Josef von Sternberg     100000                100312
# 4           244   William A. Wellman     100000                100284
# ...         ...                  ...        ...                   ...
# 1653     100000           Chris Buck        959                101291
# 1654        103           James Gray     100000                100223
# 1655        457        Anthony Russo        516                  1098
# 1656        831          Jon Favreau        462                101293
# 1657        457         Rian Johnson     100000                100878
#
#                   Cast1                   Cast2                Cast3  \
# 0        George O'Brien            Janet Gaynor  Margaret Livingston
# 1             Clara Bow  Charles 'Buddy' Rogers        Richard Arlen
# 2          Conrad Nagel              Jack Benny         John Gilbert
# 3           Gary Cooper        Marlene Dietrich       Adolphe Menjou
# 4          James Cagney             Jean Harlow         Edward Woods
# ...                 ...                     ...                  ...
# 1653       Kristen Bell            Idina Menzel             Josh Gad
# 1654          Brad Pitt         Tommy Lee Jones           Ruth Negga
# 1655  Robert Downey Jr.             Chris Evans         Mark Ruffalo
# 1656      Donald Glover                 Beyoncé           Seth Rogen
# 1657       Daniel Craig             Chris Evans         Ana de Armas
#
#                   Country of Origin Country of Origin 1 Number of Wins
# 0                     United States       United States              3
# 1                     United States       United States              1
# 2                     United States       United States              0
# 3                     United States       United States              0
# 4                     United States       United States              0
# ...                             ...                 ...            ...
# 1653                  United States       United States              0
# 1654   China, United States, Brazil               China              0
# 1655                  United States       United States              0
# 1656  United States, United Kingdom       United States              0
# 1657                  United States       United States              0
#
# [1658 rows x 23 columns]

# %%
oscarData.to_csv("fullOscarData.csv")
